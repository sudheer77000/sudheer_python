# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader

loader = UnstructuredMarkdownLoader("C:\\Sudheer\\Agentic_AI\\workspace\\python\\RAG\\knowledge.md")
docs = loader.load()
print(docs[0])
# Out:
# page_content='LangChain
#
# LangChain is a framework for building LLM applications.
#
# Components
#
# Document Loaders
#
# Text Splitters
#
# Embeddings
#
# Vector Stores' metadata={'source': 'C:\\Sudheer\\Agentic_AI\\workspace\\python\\RAG\\knowledge.md'}
