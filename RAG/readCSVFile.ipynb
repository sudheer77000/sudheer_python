# %%
from langchain_community.document_loaders import CSVLoader
csvLoader = CSVLoader("C:\\Sudheer\\Agentic_AI\\workspace\\python\\RAG\\emp.csv")
csvDocs = csvLoader.load()
print(csvDocs[0].page_content)
print(len(csvDocs))
for doc in csvLoader.lazy_load():
    print(doc.page_content)
# Out:
# id: 1
# first_name: Jesse
# last_name: McMurthy
# email: jmcmurthy0@uiuc.edu
# gender: Male
# ip_address: 139.167.175.104
# 10
# id: 1
# first_name: Jesse
# last_name: McMurthy
# email: jmcmurthy0@uiuc.edu
# gender: Male
# ip_address: 139.167.175.104
# id: 2
# first_name: Daniel
# last_name: Delve
# email: ddelve1@blogger.com
# gender: Male
# ip_address: 23.238.230.73
# id: 3
# first_name: Reagan
# last_name: Rahill
# email: rrahill2@soundcloud.com
# gender: Male
# ip_address: 52.48.91.65
# id: 4
# first_name: Melva
# last_name: Brilleman
# email: mbrilleman3@ocn.ne.jp
# gender: Female
# ip_address: 106.61.37.239
# id: 5
# first_name: Janifer
# last_name: aManger
# email: jamanger4@soundcloud.com
# gender: Female
# ip_address: 188.35.114.117
# id: 6
# first_name: Teddie
# last_name: Twigger
# email: ttwigger5@elpais.com
# gender: Male
# ip_address: 65.238.183.233
# id: 7
# first_name: Lauri
# last_name: Loyd
# email: lloyd6@berkeley.edu
# gender: Female
# ip_address: 85.39.5.157
# ...
