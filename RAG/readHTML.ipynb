# %%
from langchain_community.document_loaders import UnstructuredHTMLLoader
unstructuredHTMLLoader = UnstructuredHTMLLoader("C:\\Sudheer\\Agentic_AI\\workspace\\python\\RAG\\test.html")
unstructuredHTMLdocs=unstructuredHTMLLoader.load()
print(unstructuredHTMLdocs[0])
# Out:
# page_content='About This Page
#
# This is a standard HTML5 template featuring structural semantic tags, a hyperlink, and a placeholder image.
#
# Useful Elements
#
# First item in an unstructured list
#
# Second item in an unstructured list
#
# Learn more layout rules at W3Schools.
#
# Sample Placeholder Image' metadata={'source': 'C:\\Sudheer\\Agentic_AI\\workspace\\python\\RAG\\test.html'}
