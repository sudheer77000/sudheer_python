# %%
# Strings
s1 = "Sudheer Gundra" # Useful when strng with apostrophes
s2 = 'Sudheer Gundra' # Normal String
s3 = """Sudheer 
Gundra""" # Useful when string with multiple lines
print(s1)
print(s2)
print(s3)
print(len(s1))
print(len(s2))
print(len(s3))
print(s1.lower())
print(s1.upper())
print(s1.split())
print(s1.endswith("ra"))
print(s1.startswith("Su"))
print(s1.find("Z")) # Returns -1 if not found
#print(s1.index("Z")) # Raises ValueError if not found
print(s1.replace("e", "**"))
#for i in s1:
#    print(i)
print(s1.rstrip("dra"))
print(s1.lstrip("Sud"))
print(s1.count("e"))
s4 = "   Sudheer Gundra   "
print(s4.strip())
print(s4.lstrip())
print(s4.rstrip())
# Out:
# Sudheer Gundra
# Sudheer Gundra
# Sudheer
# Gundra
# 14
# 14
# 15
# sudheer gundra
# SUDHEER GUNDRA
# ['Sudheer', 'Gundra']
# True
# True
# -1
# Sudh****r Gundra
# Sudheer Gun
# heer Gundra
# 2
# Sudheer Gundra
# Sudheer Gundra
#    Sudheer Gundra
