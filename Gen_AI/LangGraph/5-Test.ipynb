# %%
from pydantic import BaseModel, Field
from typing import TypedDict, Literal
from langchain_groq import ChatGroq
class RouteDecision(BaseModel):
    route: Literal["RAG","LLM","WEB"] = Field(description="Node that should handle the user query")
    reasoning: str = Field(description="Reason for selecting this node")

# %%
RouteDecision.model_json_schema()
# Out:
# {'properties': {'route': {'description': 'Node that should handle the user query',
#    'enum': ['RAG', 'LLM', 'WEB'],
#    'title': 'Route',
#    'type': 'string'},
#   'reasoning': {'description': 'Reason for selecting this node',
#    'title': 'Reasoning',
#    'type': 'string'}},
#  'required': ['route', 'reasoning'],
#  'title': 'RouteDecision',
#  'type': 'object'}

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
MODEL_NAME = "openai/gpt-oss-20b"
llm = ChatGroq(
    model=MODEL_NAME,
    temperature=0.6,
    reasoning_format="hidden"
)

# %%
supervisor_model = llm.with_structured_output(schema=RouteDecision.model_json_schema(),method="json_schema")

# %%
supervisor_model.invoke("can you tell me about movies released in September  2026?")
# Out:
# {'route': 'WEB',
#  'reasoning': "The user requests information about movies released in September 2026, which is beyond the assistant's knowledge cutoff. A web search is required to retrieve current data."}
