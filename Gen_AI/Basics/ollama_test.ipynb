# %%
from langchain_ollama import ChatOllama


llm = ChatOllama(
    model="qwen2.5:3b",
    temperature=1,
    top_k=10,
    top_p=0.9,
    num_predict=50,
    repeat_penalty=1.1,
    num_ctx=100,
    #seed=4
)

response = llm.invoke("About Emaratech, Dubai")

print(response.content)
# Out:
# EmaratTech is the public brand name for Dubai's technology industry sector and the main body of the government that oversees this sector.
#
# Key points about EmaratTech (Dubai's Technology Industry Sector) include:
#
# 1. Focus: It represents a wide

# %%
load_dotenv()

DB_DIR = "career_coach_chroma_db"
api_key = os.getenv("GROQ_API_KEY")
