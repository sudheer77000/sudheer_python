# %%
from pathlib import Path
from langchain_community.document_loaders import UnstructuredMarkdownLoader

BASE_DIR = Path.cwd()
MARKDOWN_FILE = BASE_DIR / "knowledge.md"

print(MARKDOWN_FILE)

loader = UnstructuredMarkdownLoader(MARKDOWN_FILE)
docs = loader.load()
print(docs[0])
# Out:
# d:\VS\sudheer_python\sudheer_python\RAG\knowledge.md
# page_content='LangChain
#
# LangChain is a framework for building LLM applications.
#
# Components
#
# Document Loaders
#
# Text Splitters
#
# Embeddings
#
# Vector Stores' metadata={'source': 'd:\\VS\\sudheer_python\\sudheer_python\\RAG\\knowledge.md'}
