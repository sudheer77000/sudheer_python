# %%
from pathlib import Path
from langchain_community.document_loaders import JSONLoader
BASE_DIR = Path.cwd()
JSON_FILE = BASE_DIR / "Emp.json"
print(JSON_FILE)
jsonLoader = JSONLoader(JSON_FILE, 
                      jq_schema=".employees[]", 
                      text_content=False)
jsonDocs = jsonLoader.load()
print(jsonDocs[0].page_content)
# Out:
# d:\VS\sudheer_python\sudheer_python\RAG\Emp.json
# {"id": 101, "firstName": "Jane", "lastName": "Doe", "email": "jane.doe@example.com", "phone": "+1-555-0198", "hireDate": "2022-03-15", "isActive": true, "role": {"title": "Senior Software Engineer", "department": "Engineering", "salary": 115000}, "skills": ["JavaScript", "Python", "Docker", "AWS"], "managerId": 201}
