# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

documents = [
    "I love Python.I love ML. I love eating",
    "Python is easy to learn",
    "I love machine learning"
]

# Create TF-IDF Vectorizer
tfidf = TfidfVectorizer()

# Fit and Transform
X = tfidf.fit_transform(documents)

# Convert to DataFrame
df = pd.DataFrame(
    X.toarray(),
    columns=tfidf.get_feature_names_out()
)

print(df.round(3))
# Out:
#     easy  eating     is  learn  learning   love  machine     ml  python     to
# 0  0.000   0.358  0.000  0.000     0.000  0.818    0.000  0.358   0.273  0.000
# 1  0.467   0.000  0.467  0.467     0.000  0.000    0.000  0.000   0.355  0.467
# 2  0.000   0.000  0.000  0.000     0.623  0.474    0.623  0.000   0.000  0.000
