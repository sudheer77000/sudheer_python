# %%
import pandas as pd
table_records = []
table = [['Section', 'Parsing challenge', 'Why it matters for RAG'], ['Contracts', 'Dense legal text, clause numbers, cross\nreferences', 'Need section-aware chunks and citations'], ['Tables', 'Merged headers, numeric columns,\nfootnotes', 'Need row/column preservation'], ['Images', 'Architecture diagram, heatmap, scanned\nform', 'Need OCR or multimodal extraction'], ['Multi-tenant metadata', 'client_id, document_id,\ncontract_group_id', 'Need access-safe retrieval']]
cleaned_table = []
for row in table:
    #print(row)
    cleaned_row = [ cell.strip() if isinstance(cell, str) else cell for cell in row ] 
    cleaned_table.append(cleaned_row)
    df = pd.DataFrame(cleaned_table[1:], columns=cleaned_table[0])
#print(df)
print(df.to_markdown(index=False))
#print(df.to_csv(index=False))
# Out:
# | Section               | Parsing challenge                       | Why it matters for RAG                  |
# |:----------------------|:----------------------------------------|:----------------------------------------|
# | Contracts             | Dense legal text, clause numbers, cross | Need section-aware chunks and citations |
# |                       | references                              |                                         |
# | Tables                | Merged headers, numeric columns,        | Need row/column preservation            |
# |                       | footnotes                               |                                         |
# | Images                | Architecture diagram, heatmap, scanned  | Need OCR or multimodal extraction       |
# |                       | form                                    |                                         |
# ...
