# %%
from sklearn.preprocessing import OrdinalEncoder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.preprocessing import LabelEncoder
#       2 from sklearn.preprocessing import OrdinalEncoder
#       3 from sklearn.preprocessing import OneHotEncoder
# ----> 4 from sklearn.preprocessing import TermFrequencyVectorizer
#
# ImportError: cannot import name 'TermFrequencyVectorizer' from 'sklearn.preprocessing' (c:\Users\Sudheer.Gundra\AppData\Local\anaconda3\envs\sudheer_agentic_ai\Lib\site-packages\sklearn\preprocessing\__init__.py)
