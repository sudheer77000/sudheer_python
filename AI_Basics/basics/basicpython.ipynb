# %% [markdown]
# Basics Of Python

# %%
# Addition
2+3
# Out:
# 5

# %%
# Substraction
2-3
# Out:
# -1

# %%
# Multiplecation
2 * 0.9
# Out:
# 1.8

# %%
# Division
2 /9
# Out:
# 0.2222222222222222

# %%
# Square
5**2
# Out:
# 25

# %%
# String Multiplecation
"Hello " * 3
# Out:
# 'Hello Hello Hello '

# %%
# Datatype int
type(3)
# Out:
# int

# %%
# Data Types Float
type(3.14)
# Out:
# float

# %%
#Datatype String
type("Hello")
# Out:
# str

# %%
#Datatype number and string
type("42")
# Out:
# str

# %%
#Datatype String single quote
type('Hello')
# Out:
# str

# %%
# Variables And Assignment
x = 5
y = 10
z = x + y
z
type(z)
# Out:
# int

# %%
print(3 + 4)
print("Hello, World!")
print(2 * 3)
print(10 / 2)
print(5 ** 2)
print("Hello " * 3)
# Out:
# 7
# Hello, World!
# 6
# 5.0
# 25
# Hello Hello Hello

# %%
concat = "Hello " + "World"
print(concat)
# Out:
# Hello World

# %%
#Print Dynamic Values
print("The value of z is:{}".format(z))
# Out:
# The value of z is:15

# %%
# Printing Variables
print("My first name is {fname} and my last name is {lname}".format(fname="Sudheer", lname="Reddy"))
# Out:
# My first name is Sudheer and my last name is Reddy
