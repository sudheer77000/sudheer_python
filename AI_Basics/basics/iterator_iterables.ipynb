# %%
# List iterable vs iterator
my_list1 = [1, 2, 3, 4, 5]

# %%
for item in my_list1:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
my_list2 = iter(my_list1)

# %%
print(next(my_list2))  # Output: 1
# Out:
# 2

# %%
for item in my_list2:
    print(item)
# Out:
# 3
# 4
# 5
