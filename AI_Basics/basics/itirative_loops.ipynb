# %%
# For Loop
for i in range(1,101,9):
    print(i)
# Out:
# 1
# 10
# 19
# 28
# 37
# 46
# 55
# 64
# 73
# 82
# 91
# 100

# %%
a = [1,2,3,4,5]
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
b = "sudheer"
for i in b:
    print(i)
# Out:
# s
# u
# d
# h
# e
# e
# r

# %%
i = 1
while i <= 2:
    i = i + 1
    print(i)
# Out:
# 2
# 3
