# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
def greeting(name):
    return ("hello {} welcome to python functions".format(name))

print(greeting("Sudheer"))  # Output: Hello, Sudheer!
# Out:
# hello Sudheer welcome to python functions
