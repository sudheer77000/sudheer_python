# %%
print(1 + 2)
# Out:
# 3

# %%
p = input("Paste encrypted password: ")
print("Length:", len(p))
print("First 4:", p[:4])
print("Last 4:", p[-4:])
# Out:
# Length: 36
# First 4: 66ea
# Last 4: 5a8b

# %%
p = input("Paste encrypted password: ")
print(repr(p))
print("Length:", len(p))
print("Hex characters:", all(c in "0123456789abcdefABCDEF" for c in p))
# Out:
# '66ea20dd-0229-4337-ba11-985f9dc45a8b'
# Length: 36
# Hex characters: False
