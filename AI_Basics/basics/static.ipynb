# %%
class A:
    static_var1 = 42
    static_var2 = "Hello, World!"
    def print_static_vars(self):
        print(self.static_var1)
        print(self.static_var2)
        print(self.static_var3)
A.static_var3 = [1, 2, 3, 4, 5]

a = A()
a.static_var1 = 498
print(a.static_var1) 
print(a.static_var2)
print(a.static_var3)
a.static_1 = 100
print(a.static_1)
a.print_static_vars()
# Out:
# 498
# Hello, World!
# [1, 2, 3, 4, 5]
# 100
# 498
# Hello, World!
# [1, 2, 3, 4, 5]
