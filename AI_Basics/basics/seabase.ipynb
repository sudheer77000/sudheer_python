# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Load the dataset
data = sns.load_dataset('tips')
data.head()
sns.displot(data['total_bill'], kde=True, bins=5) # Kind of histogram

# %%
sns.displot(data['total_bill'], kde=False, bins=5)

# %%
sns.kdeplot(data['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.jointplot(x='total_bill', y='tip', data=data)

# %%
sns.scatterplot(x='total_bill', y='tip', data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(data)

# %%
sns.stripplot(x='day', y='total_bill', data=data, jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='total_bill', data=data)
# Out:
# <Axes: xlabel='total_bill'>

# %%
data.corr(numeric_only=True)
print(data.corr(numeric_only=True))
sns.heatmap(data.corr(numeric_only=True), annot=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
# <Axes: >

# %%
# heatmap
uniform_data = np.random.rand(10, 12)
print(uniform_data)
sns.heatmap(uniform_data, annot=True)
# Out:
# [[0.20221441 0.63388623 0.48598394 0.76947546 0.25233884 0.95038115
#   0.49272011 0.13563177 0.51112433 0.22406701 0.61194354 0.36607716]
#  [0.96624988 0.27654815 0.55204525 0.63528473 0.1502571  0.04426097
#   0.88989764 0.67974866 0.79946845 0.11938666 0.16704165 0.52062802]
#  [0.94399799 0.09994351 0.03092188 0.76991386 0.47746897 0.25182057
#   0.72296054 0.3055833  0.60360951 0.09199716 0.05087558 0.71729585]
#  [0.79166328 0.09461823 0.15660458 0.8524153  0.17790935 0.28882662
#   0.88870744 0.61183451 0.23050248 0.37215288 0.92843589 0.72060298]
#  [0.56313783 0.79772204 0.24223758 0.60762813 0.53623175 0.29544704
#   0.71686734 0.0749028  0.97649607 0.3290098  0.86064967 0.64391539]
#  [0.52503693 0.26281577 0.89736731 0.03995245 0.67916527 0.31698597
#   0.60865867 0.12324091 0.6641123  0.70263533 0.06683107 0.74876599]
#  [0.3664092  0.61611379 0.65928197 0.09460455 0.99018196 0.40788671
#   0.16481532 0.14190709 0.51532538 0.5776413  0.72047324 0.73955336]
# ...

# %%
sns.jointplot(x='tip', y='total_bill', data=data, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=data, kind='reg')

# %%
sns.pairplot(data, hue='sex')

# %%
sns.displot(data['total_bill'], kde=True, bins=5) # Kind of histogram

# %%
sns.countplot(y='day', data=data)
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.boxenplot(x='day', y='total_bill', data=data,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='total_bill', y='day', data=data,hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>
