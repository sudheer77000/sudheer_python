# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

marks = np.random.randint(500, 601, size=100)
print(marks)
count, bins, ignored = plt.hist(marks, bins=10, edgecolor='red')
print(count)
print(bins)
plt.show()
# Out:
# [520 514 509 545 559 516 528 516 598 554 530 509 547 584 501 569 526 503
#  591 520 516 518 584 533 530 557 519 577 590 529 583 502 599 556 517 568
#  544 541 554 532 539 552 581 517 598 534 515 549 560 517 529 535 571 569
#  547 588 507 593 575 537 532 570 597 546 523 546 563 508 534 534 582 586
#  594 548 511 534 515 546 504 558 563 580 509 588 547 554 582 596 571 520
#  528 537 524 544 565 540 520 541 561 500]
# [10. 12. 11. 13. 14.  8.  8.  5. 10.  9.]
# [500.  509.9 519.8 529.7 539.6 549.5 559.4 569.3 579.2 589.1 599. ]
