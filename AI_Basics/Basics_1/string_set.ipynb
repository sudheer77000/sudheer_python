# %%
sentence = ["Sudheer is from Indai",
              "He works in Dubai for Emaratech"]
for i in sentence:
    for j in i.split():
        print(j)
# Out:
# Sudheer
# is
# from
# Indai
# He
# works
# in
# Dubai
# for
# Emaratech

# %%
list_1 = [1,2,3,4,5]
list_2 = ['a','b','c','d','e']
word_to_index = {word: i for i, word in enumerate(list_2)}
index_to_word = {i: word for i, word in enumerate(list_2)}
print(word_to_index)
print(index_to_word)
# Out:
# {'a': 0, 'b': 1, 'c': 2, 'd': 3, 'e': 4}
# {0: 'a', 1: 'b', 2: 'c', 3: 'd', 4: 'e'}
