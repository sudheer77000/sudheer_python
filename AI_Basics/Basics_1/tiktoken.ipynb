# %%
import tiktoken

enc = tiktoken.encoding_for_model("gpt-4o")

text = "you are god"

tokens = enc.encode(text)

print(tokens)
print("Token count:", len(tokens))

for token in tokens:
    print(token, "->", enc.decode([token]))
# Out:
# [13320, 553, 8415]
# Token count: 3
# 13320 -> you
# 553 ->  are
# 8415 ->  god

# %%
# GPT-4o tokenizer
enc = tiktoken.get_encoding("o200k_base")

text = "Wednesday is today"

token_ids = enc.encode(text)
tokens = [enc.decode([t]) for t in token_ids]

print("Token IDs:", token_ids)
print("Tokens:", tokens)
# Out:
# Token IDs: [26200, 382, 4044]
# Tokens: ['Wednesday', ' is', ' today']
