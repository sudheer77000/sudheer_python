# %%
#if condition:
a = True
if type(a) == int:
    print("a is an integer")
elif type(a) == float:
    print("a is a float")
elif type(a) == str:
    print("a is a string")
elif type(a) == bool:
    print("a is a boolean")
else:
    print("a is of unknown type")
# Out:
# a is a boolean
