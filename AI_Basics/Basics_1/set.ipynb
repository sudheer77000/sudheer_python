# %%
# Set Elements
s1 = {8,1, 2, 3, 4, 5}
s2 = {9,4, 5, 6, 7, 8}
#method
print(type(s1))
s1.add(6)
print(s1)
s1.pop()
print(s1)
s1.add("Sudheer")
print(s1)
s1.update([10,11,12])
print(s1)
#Operations
print("========== Operations ==========")
s3 = {1, 2, 3}
s4 = {3, 4, 5}
s5 = {1,2,3,4,5}
print(s3.union(s4))
print(s3.intersection(s4))
print(s3.difference(s4))
print(s4.difference(s3))
print(s3.symmetric_difference(s4))
print(s3.issubset(s5))
print(s5.issuperset(s4))
# Out:
# <class 'set'>
# {1, 2, 3, 4, 5, 6, 8}
# {2, 3, 4, 5, 6, 8}
# {2, 3, 4, 5, 6, 'Sudheer', 8}
# {2, 3, 4, 5, 6, 8, 10, 11, 12, 'Sudheer'}
# ========== Operations ==========
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {4, 5}
# {1, 2, 4, 5}
# True
# True
