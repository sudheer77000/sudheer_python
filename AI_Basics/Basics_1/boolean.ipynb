# %%
# Boolean
is_raining = True
is_sunny = False
print("Is it raining_?", is_raining)
print("Is it sunny?", is_sunny)
print(type(is_raining))  # Output: <class 'bool'>
print(bool(""))    # Output: <class 'bool'>
# Out:
# Is it raining_? True
# Is it sunny? False
# <class 'bool'>
# False
