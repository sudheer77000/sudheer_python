# %%
# Arguments
def fullName(firstName,lastName,gender="unknown"):
    return "First Name "+firstName+", Last Name "+lastName+", Gender "+gender
print(fullName("Sudheer","Gundra","Male"))
print(fullName(lastName="Arun",firstName="Gundra",gender="female"))
# Out:
# First Name Sudheer, Last Name Gundra, Gender Male
# First Name Gundra, Last Name Arun, Gender female
